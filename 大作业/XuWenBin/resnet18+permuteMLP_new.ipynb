# %%
# %pylab inline 
import matplotlib.pyplot as plt 
import numpy as np
plt.plot(np.sin(np.linspace(0,2*np.pi, 100)))
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
from basic_tools import *
# 有时候下载数据集会报错，加下边这两行就可以了
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
def get_data_loaders(train_batch_size, test_batch_size, transform_train=None, transform_test=None):
    # 图像变换,预处理操作，
    if transform_train == None:
        transform_train = transforms.Compose([
            transforms.RandomCrop(32, padding=4),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ])
    if transform_test == None:
        transform_test = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ])
    train_data = torchvision.datasets.CIFAR100(
        root="./data", train=True, download=False, transform=transform_train)
    trainloader = torch.utils.data.DataLoader(
        train_data, batch_size=train_batch_size, shuffle=True, num_workers=0)
    test_data = torchvision.datasets.CIFAR100(
        root="./data", train=False, download=False, transform=transform_test)
    testloader = torch.utils.data.DataLoader(
        test_data, batch_size=test_batch_size, shuffle=False, num_workers=0)

    return trainloader, testloader

# %%
batch_size = 512
trainloader, testloader = get_data_loaders(128, 128)

# %%
images, labels = next(iter(trainloader))
print(images.shape, labels.shape)
# Out:
# torch.Size([128, 3, 32, 32]) torch.Size([128])

# %%
class Mlp(nn.Module):
    def __init__(self, in_features, hidden_features=None, out_features=None, act_layer=nn.GELU, drop=0.5) -> None:
        super().__init__()
        out_features = out_features or in_features
        hidden_features = hidden_features or in_features
        self.fc1 = nn.Linear(in_features, hidden_features)
        self.act = act_layer()
        self.fc2 = nn.Linear(hidden_features, out_features)
        self.drop = nn.Dropout(drop)

    def forward(self, x):
        x = self.fc1(x)
        x = self.act(x)
        x = self.drop(x)
        x = self.fc2(x)
        x = self.drop(x)
        return x


class WeightedPermuteMLP(nn.Module):
    def __init__(self, n, c, proj_drop=0.3) -> None:
        super().__init__()
        self.n = n
        # self.norm1 = nn.LayerNorm(c)
        self.mlp_c = nn.Linear(c, c)
        self.mlp_h = nn.Linear(c, c)
        self.mlp_w = nn.Linear(c, c)
        self.reweight = Mlp(c, c // 4, c * 3)
        self.proj = nn.Linear(c, c)
        self.proj_drop = nn.Dropout(proj_drop)
        # self.norm2 = nn.LayerNorm(c)

    def forward(self, x):
        pre = x
        B, C, H, W = x.shape
        x = x.permute(0, 2, 3, 1)
        S = C // self.n


        h = x.reshape(B, H, W, self.n, S).permute(
            0, 3, 2, 1, 4).reshape(B, self.n, W, H * S)
        h = self.mlp_h(h).reshape(B, self.n, W, H, S).permute(
            0, 3, 2, 1, 4).reshape(B, H, W, C)

        w = x.reshape(B, H, W, self.n, S).permute(
            0, 1, 3, 2, 4).reshape(B, H, self.n, W * S)
        # print(w.shape)
        w = self.mlp_w(w).reshape(B, H, self.n, W, S).permute(
            0, 1, 3, 2, 4).reshape(B, H, W, C)

        # print(x.shape)
        c = self.mlp_c(x)

        a = (h + w + c).permute(0, 3, 1, 2).flatten(2).mean(2)
        a = self.reweight(a).reshape(B, C, 3).permute(
            2, 0, 1).softmax(dim=0).unsqueeze(2).unsqueeze(2)

        # print(h.shape, w.shape, c.shape, a.shape)
        # x = (h + w + c) / 3
        x = h * a[0] + w * a[1] + c * a[2]

        x = self.proj(x)
        x = self.proj_drop(x)

        x = x.permute(0, 3, 1, 2)
        x = pre + x
        # x = self.norm2(x)

        return x

# %%
class BasicBlock_v2(nn.Module):
    # 按照何凯明的做法优化下，然后又给每一个残差块加了个dropout,https://blog.csdn.net/u013817537/article/details/116500611
    # dropout试了下，负优化，删了
    def __init__(self, in_channels, out_channels, stride=1, downsample=None, n=16):
        super(BasicBlock_v2, self).__init__()
        self.conv1 = nn.Conv2d(
            in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.relu = nn.ReLU(inplace=True)
        # self.conv2 = nn.Conv2d(out_channels, out_channels,
        #                        kernel_size=3, stride=1, padding=1, bias=False)
        self.conv2 = WeightedPermuteMLP(n, out_channels)
        self.bn2 = nn.BatchNorm2d(out_channels)
        self.downsample = downsample
        # self.dropout = nn.Dropout(p=0.5)

    def forward(self, x):
        identity = x

        out = self.bn1(x)
        out = self.relu(out)
        out = self.conv1(out)
        out = self.bn2(out)
        out = self.relu(out)
        out = self.conv2(out)
        # out=self.dropout(out)
        if self.downsample is not None:
            identity = self.downsample(x)
        out += identity

        return out

# %%
class ResNet(nn.Module):
    def __init__(self, block, layers, num_classes=100):
        super(ResNet, self).__init__()
        self.in_channels = 64
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn = nn.BatchNorm2d(64)
        self.relu = nn.ReLU(inplace=True)
        self.n = 32
        self.layer1 = self.make_layer(block, 64, layers[0])
        # self.permute1 = WeightedPermuteMLP(32, 32, 32, 64)
        # self.permute1 = WeightedPermuteMLP(8, 8, 8, 64)
        self.n = 16
        self.layer2 = self.make_layer(block, 128, layers[1], 2)
        # self.permute2 = WeightedPermuteMLP(16, 16, 16, 128)
        # self.permute2 = WeightedPermuteMLP(4, 4, 4, 128)
        self.n = 8 
        self.layer3 = self.make_layer(block, 256, layers[2], 2)
        # self.permute3 = WeightedPermuteMLP(8, 8, 8, 256)
        # self.permute3 = WeightedPermuteMLP(2, 2, 2, 256)
        self.n = 4
        self.layer4 = self.make_layer(block, 512, layers[3], 2)
        # self.permute4 = WeightedPermuteMLP(4, 4, 4, 512)
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(512, num_classes)

    def make_layer(self, block, out_channels, blocks, stride=1):
        downsample = None
        if stride != 1 or self.in_channels != out_channels:
            downsample = nn.Sequential(
                nn.Conv2d(self.in_channels, out_channels,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )
        layers = []
        layers.append(
            block(self.in_channels, out_channels, stride, downsample, n=self.n))
        self.in_channels = out_channels
        for i in range(1, blocks):
            layers.append(block(out_channels, out_channels, n=self.n))

        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn(out)
        out = self.relu(out)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.avg_pool(out)
        out = torch.flatten(out, 1)
        out = self.fc(out)
        return out

# %%
net = ResNet(BasicBlock_v2, [2, 2, 2, 2])
image, label = next(iter(trainloader))
net(image)
# print(net)
# Out:
# tensor([[-0.0751,  0.2530,  0.1181,  ...,  0.1890, -0.2069, -0.9962],
#         [ 2.5027,  0.7762,  0.5870,  ..., -1.0036,  0.4553, -1.0737],
#         [ 0.6171,  0.5827,  0.2151,  ..., -0.3325,  0.1834, -1.2293],
#         ...,
#         [-0.0564,  0.2593, -0.0263,  ...,  0.2663,  0.1298, -1.0069],
#         [ 0.1804,  0.4002,  0.2730,  ..., -0.2730, -0.3663, -0.6073],
#         [ 0.7732,  0.2798,  0.3221,  ..., -0.2873, -0.5672, -0.7607]],
#        grad_fn=<AddmmBackward0>)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
learning_rate = 0.05
momentum = 0.9
weight_decay = 0.0001
epochs = 150
model = ResNet(BasicBlock_v2, [2, 2, 2, 2]).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optimizer = optim.SGD(model.parameters(
), lr=learning_rate, momentum=momentum, weight_decay=weight_decay)
# Out:
# cuda

# %%
# 训练之
train_lossa, test_lossa = [], []
train_acca, test_acca = [], []
train_top5_acca, test_top5_acca = [], []
for epoch in range(epochs):
    train_loss, train_acc, train_top5_acc = train(
        model, trainloader, criterion, optimizer, device)
    test_loss, test_acc, test_top5_acc = test(
        model, testloader, criterion, device)
    print('epoch:{},train_loss:{:.4f},train_acc:{:.4f},train_top5_acc:{:.4f},test_loss:{:.4f},test_acc:{:.4f},test_top5_acc:{:.4f}'.format(
        epoch, train_loss, train_acc, train_top5_acc, test_loss, test_acc, test_top5_acc))
    train_lossa.append(train_loss)
    test_lossa.append(test_loss)
    train_acca.append(train_acc)
    test_acca.append(test_acc)
    train_top5_acca.append(train_top5_acc)
    test_top5_acca.append(test_top5_acc)
# Out:
# epoch:0,train_loss:3.7419,train_acc:12.6060,train_top5_acc:35.9280,test_loss:3.3511,test_acc:19.7300,test_top5_acc:48.2400
# epoch:1,train_loss:2.9059,train_acc:26.7140,train_top5_acc:58.0260,test_loss:2.6811,test_acc:32.1900,test_top5_acc:63.9300
# epoch:2,train_loss:2.4206,train_acc:36.5120,train_top5_acc:69.2080,test_loss:2.5178,test_acc:35.6300,test_top5_acc:67.1900
# epoch:3,train_loss:2.1118,train_acc:43.3600,train_top5_acc:75.5760,test_loss:2.1694,test_acc:43.4000,test_top5_acc:74.9500
# epoch:4,train_loss:1.9007,train_acc:48.0260,train_top5_acc:79.5180,test_loss:2.0208,test_acc:47.0500,test_top5_acc:76.7000
# epoch:5,train_loss:1.7372,train_acc:52.0360,train_top5_acc:82.2940,test_loss:1.8753,test_acc:49.3200,test_top5_acc:79.8800
# epoch:6,train_loss:1.5938,train_acc:55.4160,train_top5_acc:84.6740,test_loss:1.6654,test_acc:54.6100,test_top5_acc:83.3000
# epoch:7,train_loss:1.4709,train_acc:58.3000,train_top5_acc:86.6660,test_loss:1.6582,test_acc:55.3200,test_top5_acc:83.7600
# epoch:8,train_loss:1.3675,train_acc:60.9460,train_top5_acc:88.1280,test_loss:1.5514,test_acc:56.9500,test_top5_acc:85.3500
# epoch:9,train_loss:1.2688,train_acc:63.4720,train_top5_acc:89.6280,test_loss:1.5543,test_acc:57.1000,test_top5_acc:85.7800
# epoch:10,train_loss:1.1903,train_acc:65.4320,train_top5_acc:90.8640,test_loss:1.5024,test_acc:59.1800,test_top5_acc:86.3400
# epoch:11,train_loss:1.1110,train_acc:67.5680,train_top5_acc:91.7980,test_loss:1.4330,test_acc:60.5300,test_top5_acc:87.5500
# epoch:12,train_loss:1.0485,train_acc:68.9640,train_top5_acc:92.7380,test_loss:1.4501,test_acc:61.1300,test_top5_acc:87.4100
# epoch:13,train_loss:0.9814,train_acc:70.8680,train_top5_acc:93.3720,test_loss:1.4212,test_acc:61.1000,test_top5_acc:87.5000
# epoch:14,train_loss:0.9230,train_acc:72.2100,train_top5_acc:94.3520,test_loss:1.3877,test_acc:62.6000,test_top5_acc:88.0700
# epoch:15,train_loss:0.8733,train_acc:73.8100,train_top5_acc:94.8220,test_loss:1.3814,test_acc:62.9900,test_top5_acc:88.3900
# epoch:16,train_loss:0.8128,train_acc:75.2960,train_top5_acc:95.4340,test_loss:1.4169,test_acc:62.5400,test_top5_acc:88.4800
# epoch:17,train_loss:0.7726,train_acc:76.3400,train_top5_acc:95.9420,test_loss:1.4574,test_acc:62.6200,test_top5_acc:88.3500
# epoch:18,train_loss:0.7236,train_acc:77.7120,train_top5_acc:96.4520,test_loss:1.3758,test_acc:64.0000,test_top5_acc:88.7600
# epoch:19,train_loss:0.6801,train_acc:78.8320,train_top5_acc:96.9340,test_loss:1.4112,test_acc:63.9500,test_top5_acc:88.8200
# epoch:20,train_loss:0.6503,train_acc:79.8820,train_top5_acc:97.1460,test_loss:1.4302,test_acc:64.2600,test_top5_acc:88.6400
# epoch:21,train_loss:0.6119,train_acc:80.8360,train_top5_acc:97.6120,test_loss:1.4160,test_acc:64.5200,test_top5_acc:88.7000
# epoch:22,train_loss:0.5707,train_acc:82.0120,train_top5_acc:97.8580,test_loss:1.4354,test_acc:63.7000,test_top5_acc:88.5900
# epoch:23,train_loss:0.5466,train_acc:82.6560,train_top5_acc:98.0100,test_loss:1.4230,test_acc:64.7800,test_top5_acc:88.7000
# epoch:24,train_loss:0.5134,train_acc:83.7140,train_top5_acc:98.2660,test_loss:1.4140,test_acc:64.4400,test_top5_acc:88.8100
# epoch:25,train_loss:0.4850,train_acc:84.4620,train_top5_acc:98.4920,test_loss:1.4583,test_acc:64.7200,test_top5_acc:89.3800
# epoch:26,train_loss:0.4689,train_acc:84.8680,train_top5_acc:98.6820,test_loss:1.5094,test_acc:65.1700,test_top5_acc:89.0900
# epoch:27,train_loss:0.4468,train_acc:85.5600,train_top5_acc:98.8120,test_loss:1.5341,test_acc:64.9600,test_top5_acc:88.5700
# epoch:28,train_loss:0.4172,train_acc:86.4740,train_top5_acc:98.9220,test_loss:1.5456,test_acc:65.2700,test_top5_acc:88.6600
# epoch:29,train_loss:0.4107,train_acc:86.5720,train_top5_acc:99.0380,test_loss:1.4910,test_acc:65.3500,test_top5_acc:89.4400
# epoch:30,train_loss:0.3808,train_acc:87.7940,train_top5_acc:99.0840,test_loss:1.5444,test_acc:65.0900,test_top5_acc:88.9700
# epoch:31,train_loss:0.3704,train_acc:88.0760,train_top5_acc:99.1580,test_loss:1.5042,test_acc:65.2500,test_top5_acc:89.2600
# epoch:32,train_loss:0.3577,train_acc:88.3400,train_top5_acc:99.2760,test_loss:1.5737,test_acc:65.0300,test_top5_acc:89.3600
# epoch:33,train_loss:0.3354,train_acc:88.9500,train_top5_acc:99.4220,test_loss:1.5526,test_acc:65.6700,test_top5_acc:89.1600
# epoch:34,train_loss:0.3313,train_acc:89.2580,train_top5_acc:99.4160,test_loss:1.5577,test_acc:65.9500,test_top5_acc:89.1100
# epoch:35,train_loss:0.3162,train_acc:89.7600,train_top5_acc:99.5240,test_loss:1.6577,test_acc:64.6100,test_top5_acc:89.1000
# epoch:36,train_loss:0.2896,train_acc:90.6160,train_top5_acc:99.5880,test_loss:1.5513,test_acc:66.5100,test_top5_acc:89.7200
# epoch:37,train_loss:0.2915,train_acc:90.4000,train_top5_acc:99.5880,test_loss:1.5609,test_acc:65.4100,test_top5_acc:89.1200
# epoch:38,train_loss:0.2789,train_acc:90.9720,train_top5_acc:99.5980,test_loss:1.7503,test_acc:64.6500,test_top5_acc:88.0900
# epoch:39,train_loss:0.2802,train_acc:90.8080,train_top5_acc:99.5980,test_loss:1.6273,test_acc:65.6000,test_top5_acc:88.9100
# epoch:40,train_loss:0.2683,train_acc:91.2720,train_top5_acc:99.6560,test_loss:1.6906,test_acc:64.8000,test_top5_acc:88.7900
# epoch:41,train_loss:0.2533,train_acc:91.8020,train_top5_acc:99.6840,test_loss:1.6909,test_acc:65.2600,test_top5_acc:88.6500
# epoch:42,train_loss:0.2505,train_acc:91.8900,train_top5_acc:99.6960,test_loss:1.7784,test_acc:63.9500,test_top5_acc:88.2000
# epoch:43,train_loss:0.2410,train_acc:92.2460,train_top5_acc:99.6880,test_loss:1.6919,test_acc:65.3100,test_top5_acc:89.4000
# epoch:44,train_loss:0.2311,train_acc:92.3800,train_top5_acc:99.7600,test_loss:1.6619,test_acc:65.7500,test_top5_acc:88.7300
# epoch:45,train_loss:0.2226,train_acc:92.6620,train_top5_acc:99.7620,test_loss:1.6680,test_acc:66.9900,test_top5_acc:89.4200
# epoch:46,train_loss:0.2315,train_acc:92.5600,train_top5_acc:99.7100,test_loss:1.7159,test_acc:65.4500,test_top5_acc:89.3700
# epoch:47,train_loss:0.2275,train_acc:92.5520,train_top5_acc:99.7700,test_loss:1.7067,test_acc:65.7400,test_top5_acc:88.8400
# epoch:48,train_loss:0.2098,train_acc:93.2260,train_top5_acc:99.7840,test_loss:1.6453,test_acc:66.6600,test_top5_acc:89.4600
# epoch:49,train_loss:0.1987,train_acc:93.6180,train_top5_acc:99.8380,test_loss:1.6666,test_acc:66.5700,test_top5_acc:89.2700
# epoch:50,train_loss:0.2052,train_acc:93.3080,train_top5_acc:99.8020,test_loss:1.7269,test_acc:65.9000,test_top5_acc:88.6000
# epoch:51,train_loss:0.1988,train_acc:93.4580,train_top5_acc:99.8320,test_loss:1.7081,test_acc:66.2800,test_top5_acc:89.1700
# epoch:52,train_loss:0.1956,train_acc:93.6520,train_top5_acc:99.8240,test_loss:1.7581,test_acc:65.6400,test_top5_acc:89.0700
# epoch:53,train_loss:0.2010,train_acc:93.3540,train_top5_acc:99.8000,test_loss:1.7161,test_acc:66.1200,test_top5_acc:89.0300
# epoch:54,train_loss:0.2003,train_acc:93.4780,train_top5_acc:99.8080,test_loss:1.7256,test_acc:66.5600,test_top5_acc:89.1500
# epoch:55,train_loss:0.1995,train_acc:93.5780,train_top5_acc:99.8100,test_loss:1.7273,test_acc:66.6100,test_top5_acc:89.1200
# epoch:56,train_loss:0.1866,train_acc:93.9140,train_top5_acc:99.8320,test_loss:1.7771,test_acc:65.1000,test_top5_acc:88.4800
# epoch:57,train_loss:0.1906,train_acc:93.8860,train_top5_acc:99.8180,test_loss:1.7973,test_acc:65.9400,test_top5_acc:88.8900
# epoch:58,train_loss:0.1811,train_acc:94.1220,train_top5_acc:99.8520,test_loss:1.7049,test_acc:66.8000,test_top5_acc:89.1600
# epoch:59,train_loss:0.1649,train_acc:94.6340,train_top5_acc:99.8740,test_loss:1.7627,test_acc:66.5700,test_top5_acc:89.2400
# epoch:60,train_loss:0.1568,train_acc:94.9680,train_top5_acc:99.8760,test_loss:1.7809,test_acc:66.6500,test_top5_acc:89.3100
# epoch:61,train_loss:0.1832,train_acc:93.9460,train_top5_acc:99.8580,test_loss:1.8487,test_acc:66.1600,test_top5_acc:88.5900
# epoch:62,train_loss:0.1732,train_acc:94.3700,train_top5_acc:99.8340,test_loss:1.6788,test_acc:66.2400,test_top5_acc:89.2500
# epoch:63,train_loss:0.1617,train_acc:94.7700,train_top5_acc:99.8900,test_loss:1.6903,test_acc:66.0100,test_top5_acc:89.3500
# epoch:64,train_loss:0.1685,train_acc:94.5960,train_top5_acc:99.8620,test_loss:1.7539,test_acc:66.2900,test_top5_acc:89.0000
# epoch:65,train_loss:0.1644,train_acc:94.7400,train_top5_acc:99.8740,test_loss:1.7989,test_acc:65.3800,test_top5_acc:88.6300
# epoch:66,train_loss:0.1687,train_acc:94.5900,train_top5_acc:99.8680,test_loss:1.7947,test_acc:65.4500,test_top5_acc:88.9000
# epoch:67,train_loss:0.1738,train_acc:94.2960,train_top5_acc:99.8480,test_loss:1.8009,test_acc:66.1800,test_top5_acc:88.9900
# epoch:68,train_loss:0.1616,train_acc:94.7760,train_top5_acc:99.8680,test_loss:1.8335,test_acc:65.6600,test_top5_acc:88.4700
# epoch:69,train_loss:0.1520,train_acc:95.0580,train_top5_acc:99.9160,test_loss:1.8535,test_acc:65.6500,test_top5_acc:88.7400
# epoch:70,train_loss:0.1544,train_acc:94.9320,train_top5_acc:99.8280,test_loss:1.7640,test_acc:66.6500,test_top5_acc:88.9500
# epoch:71,train_loss:0.1578,train_acc:94.9680,train_top5_acc:99.8920,test_loss:1.8186,test_acc:65.7000,test_top5_acc:88.5900
# epoch:72,train_loss:0.1644,train_acc:94.6900,train_top5_acc:99.8340,test_loss:1.7137,test_acc:66.8400,test_top5_acc:89.2200
# epoch:73,train_loss:0.1501,train_acc:95.1920,train_top5_acc:99.9060,test_loss:1.7569,test_acc:66.4600,test_top5_acc:88.7400
# epoch:74,train_loss:0.1509,train_acc:95.1420,train_top5_acc:99.8740,test_loss:1.7319,test_acc:67.0300,test_top5_acc:89.5300
# epoch:75,train_loss:0.1542,train_acc:95.0280,train_top5_acc:99.8600,test_loss:1.7190,test_acc:67.2900,test_top5_acc:88.9500
# epoch:76,train_loss:0.1475,train_acc:95.2460,train_top5_acc:99.8760,test_loss:1.7034,test_acc:66.3800,test_top5_acc:88.9000
# epoch:77,train_loss:0.1437,train_acc:95.3820,train_top5_acc:99.9000,test_loss:1.7736,test_acc:66.8900,test_top5_acc:88.8400
# epoch:78,train_loss:0.1518,train_acc:95.0500,train_top5_acc:99.8720,test_loss:1.7972,test_acc:66.7200,test_top5_acc:88.5800
# epoch:79,train_loss:0.1582,train_acc:94.8940,train_top5_acc:99.8740,test_loss:1.8476,test_acc:65.6900,test_top5_acc:88.4600
# epoch:80,train_loss:0.1449,train_acc:95.3840,train_top5_acc:99.8980,test_loss:1.7348,test_acc:67.0000,test_top5_acc:89.1100
# epoch:81,train_loss:0.1416,train_acc:95.5060,train_top5_acc:99.9060,test_loss:1.8398,test_acc:66.5800,test_top5_acc:88.7400
# epoch:82,train_loss:0.1514,train_acc:95.1200,train_top5_acc:99.9080,test_loss:1.7284,test_acc:67.1600,test_top5_acc:88.9100
# epoch:83,train_loss:0.1518,train_acc:95.0880,train_top5_acc:99.8960,test_loss:1.7655,test_acc:67.0600,test_top5_acc:88.5300
# epoch:84,train_loss:0.1481,train_acc:95.2020,train_top5_acc:99.8800,test_loss:1.8894,test_acc:65.7500,test_top5_acc:88.3300
# epoch:85,train_loss:0.1481,train_acc:95.3040,train_top5_acc:99.8720,test_loss:1.8875,test_acc:65.5900,test_top5_acc:88.1400
# epoch:86,train_loss:0.1475,train_acc:95.2460,train_top5_acc:99.9080,test_loss:1.7826,test_acc:65.8700,test_top5_acc:88.5300
# epoch:87,train_loss:0.1483,train_acc:95.1580,train_top5_acc:99.9040,test_loss:1.7917,test_acc:66.8200,test_top5_acc:89.1000
# epoch:88,train_loss:0.1363,train_acc:95.6140,train_top5_acc:99.9120,test_loss:1.8242,test_acc:67.1800,test_top5_acc:89.2800
# epoch:89,train_loss:0.1454,train_acc:95.2860,train_top5_acc:99.8820,test_loss:1.7290,test_acc:66.6800,test_top5_acc:88.7300
# epoch:90,train_loss:0.1359,train_acc:95.6300,train_top5_acc:99.9160,test_loss:1.8005,test_acc:66.6400,test_top5_acc:88.7500
# epoch:91,train_loss:0.1380,train_acc:95.5640,train_top5_acc:99.8820,test_loss:1.8573,test_acc:67.0600,test_top5_acc:88.8000
# epoch:92,train_loss:0.1409,train_acc:95.5960,train_top5_acc:99.8780,test_loss:1.8593,test_acc:65.9900,test_top5_acc:88.3800
# epoch:93,train_loss:0.1476,train_acc:95.2720,train_top5_acc:99.9000,test_loss:1.7552,test_acc:67.3400,test_top5_acc:89.3100
# epoch:94,train_loss:0.1388,train_acc:95.6500,train_top5_acc:99.8940,test_loss:1.9059,test_acc:66.4400,test_top5_acc:88.4400
# epoch:95,train_loss:0.1294,train_acc:95.8480,train_top5_acc:99.9160,test_loss:1.7827,test_acc:66.4600,test_top5_acc:88.9500
# epoch:96,train_loss:0.1310,train_acc:95.8320,train_top5_acc:99.9120,test_loss:1.8144,test_acc:66.7100,test_top5_acc:88.8500
# epoch:97,train_loss:0.1416,train_acc:95.3320,train_top5_acc:99.8980,test_loss:1.8169,test_acc:66.5100,test_top5_acc:88.2800
# epoch:98,train_loss:0.1382,train_acc:95.5860,train_top5_acc:99.8880,test_loss:1.7835,test_acc:66.4500,test_top5_acc:89.0300
# epoch:99,train_loss:0.1325,train_acc:95.7180,train_top5_acc:99.9080,test_loss:1.7814,test_acc:66.6700,test_top5_acc:88.9400
# epoch:100,train_loss:0.1281,train_acc:96.0100,train_top5_acc:99.9120,test_loss:1.7565,test_acc:66.9600,test_top5_acc:89.3100
# epoch:101,train_loss:0.1247,train_acc:96.1040,train_top5_acc:99.9120,test_loss:1.8162,test_acc:66.4100,test_top5_acc:88.4400
# epoch:102,train_loss:0.1373,train_acc:95.5420,train_top5_acc:99.9080,test_loss:1.8170,test_acc:66.6200,test_top5_acc:89.4200
# epoch:103,train_loss:0.1329,train_acc:95.7320,train_top5_acc:99.9120,test_loss:1.8513,test_acc:66.0400,test_top5_acc:88.4000
# epoch:104,train_loss:0.1443,train_acc:95.4080,train_top5_acc:99.8660,test_loss:1.7352,test_acc:67.1700,test_top5_acc:88.7500
# epoch:105,train_loss:0.1239,train_acc:96.0680,train_top5_acc:99.9240,test_loss:1.6936,test_acc:67.8100,test_top5_acc:89.4700
# epoch:106,train_loss:0.1340,train_acc:95.7400,train_top5_acc:99.8920,test_loss:1.8512,test_acc:65.8800,test_top5_acc:88.3800
# epoch:107,train_loss:0.1336,train_acc:95.6640,train_top5_acc:99.9240,test_loss:1.7893,test_acc:67.3200,test_top5_acc:88.9500
# epoch:108,train_loss:0.1365,train_acc:95.6480,train_top5_acc:99.8960,test_loss:1.7795,test_acc:67.0500,test_top5_acc:89.1000
# epoch:109,train_loss:0.1311,train_acc:95.8520,train_top5_acc:99.9200,test_loss:1.7990,test_acc:66.5100,test_top5_acc:87.9800
# epoch:110,train_loss:0.1352,train_acc:95.7000,train_top5_acc:99.9240,test_loss:1.8157,test_acc:66.9200,test_top5_acc:88.8800
# epoch:111,train_loss:0.1339,train_acc:95.7100,train_top5_acc:99.8840,test_loss:1.7322,test_acc:67.3100,test_top5_acc:89.2600
# epoch:112,train_loss:0.1265,train_acc:95.9300,train_top5_acc:99.9300,test_loss:1.7793,test_acc:67.0600,test_top5_acc:89.0600
# epoch:113,train_loss:0.1339,train_acc:95.6240,train_top5_acc:99.8880,test_loss:1.7553,test_acc:67.9700,test_top5_acc:89.6000
# epoch:114,train_loss:0.1288,train_acc:95.9040,train_top5_acc:99.9160,test_loss:1.8247,test_acc:66.6000,test_top5_acc:89.1700
# epoch:115,train_loss:0.1301,train_acc:95.8600,train_top5_acc:99.9180,test_loss:1.7721,test_acc:67.3500,test_top5_acc:88.8900
# epoch:116,train_loss:0.1435,train_acc:95.4520,train_top5_acc:99.9040,test_loss:1.7498,test_acc:66.8400,test_top5_acc:88.7700
# epoch:117,train_loss:0.1302,train_acc:95.8220,train_top5_acc:99.8940,test_loss:1.8612,test_acc:66.3800,test_top5_acc:88.9100
# epoch:118,train_loss:0.1272,train_acc:95.9320,train_top5_acc:99.9200,test_loss:1.8983,test_acc:65.4100,test_top5_acc:88.2700
# epoch:119,train_loss:0.1556,train_acc:94.9840,train_top5_acc:99.8620,test_loss:1.7915,test_acc:66.7400,test_top5_acc:88.7000
# epoch:120,train_loss:0.1317,train_acc:95.7680,train_top5_acc:99.9220,test_loss:1.7275,test_acc:67.5400,test_top5_acc:88.5500
# epoch:121,train_loss:0.1165,train_acc:96.3240,train_top5_acc:99.9380,test_loss:1.7658,test_acc:67.0300,test_top5_acc:88.9500
# epoch:122,train_loss:0.1206,train_acc:96.1540,train_top5_acc:99.9080,test_loss:1.7563,test_acc:66.8500,test_top5_acc:89.5500
# epoch:123,train_loss:0.1162,train_acc:96.2700,train_top5_acc:99.9360,test_loss:1.8363,test_acc:66.6400,test_top5_acc:88.5800
# epoch:124,train_loss:0.1208,train_acc:96.0840,train_top5_acc:99.9360,test_loss:1.7894,test_acc:66.6100,test_top5_acc:89.3700
# epoch:125,train_loss:0.1249,train_acc:96.0160,train_top5_acc:99.9300,test_loss:1.8628,test_acc:66.2600,test_top5_acc:88.2500
# epoch:126,train_loss:0.1342,train_acc:95.7040,train_top5_acc:99.8880,test_loss:1.8677,test_acc:66.2800,test_top5_acc:88.7800
# epoch:127,train_loss:0.1267,train_acc:95.9740,train_top5_acc:99.9080,test_loss:1.7992,test_acc:66.4200,test_top5_acc:89.1800
# epoch:128,train_loss:0.1233,train_acc:96.1160,train_top5_acc:99.9220,test_loss:1.8438,test_acc:66.5400,test_top5_acc:89.0400
# epoch:129,train_loss:0.1254,train_acc:95.8920,train_top5_acc:99.9140,test_loss:1.7587,test_acc:66.8900,test_top5_acc:89.0600
# epoch:130,train_loss:0.1282,train_acc:95.9260,train_top5_acc:99.9120,test_loss:1.7954,test_acc:66.5400,test_top5_acc:88.6800
# epoch:131,train_loss:0.1301,train_acc:95.7300,train_top5_acc:99.9100,test_loss:1.7664,test_acc:66.2400,test_top5_acc:88.9900
# epoch:132,train_loss:0.1264,train_acc:95.9960,train_top5_acc:99.9380,test_loss:1.8148,test_acc:66.5000,test_top5_acc:88.4500
# epoch:133,train_loss:0.1216,train_acc:96.2060,train_top5_acc:99.9140,test_loss:1.7541,test_acc:67.3000,test_top5_acc:88.7600
# epoch:134,train_loss:0.1208,train_acc:96.0840,train_top5_acc:99.9420,test_loss:1.8009,test_acc:67.3100,test_top5_acc:89.1000
# epoch:135,train_loss:0.1243,train_acc:96.1140,train_top5_acc:99.9320,test_loss:1.7722,test_acc:67.3500,test_top5_acc:89.0500
# epoch:136,train_loss:0.1092,train_acc:96.5560,train_top5_acc:99.9540,test_loss:1.8529,test_acc:66.4400,test_top5_acc:88.3300
# epoch:137,train_loss:0.1223,train_acc:96.1060,train_top5_acc:99.9060,test_loss:1.7554,test_acc:67.8000,test_top5_acc:89.4000
# epoch:138,train_loss:0.1152,train_acc:96.4160,train_top5_acc:99.9280,test_loss:1.8078,test_acc:67.0500,test_top5_acc:88.4500
# epoch:139,train_loss:0.1186,train_acc:96.1520,train_top5_acc:99.9340,test_loss:1.9030,test_acc:66.8800,test_top5_acc:88.1600
# epoch:140,train_loss:0.1309,train_acc:95.9060,train_top5_acc:99.8900,test_loss:1.8743,test_acc:66.5600,test_top5_acc:88.2500
# epoch:141,train_loss:0.1347,train_acc:95.7380,train_top5_acc:99.9220,test_loss:1.7741,test_acc:66.8600,test_top5_acc:88.5500
# epoch:142,train_loss:0.1200,train_acc:96.2040,train_top5_acc:99.9180,test_loss:1.7818,test_acc:67.0600,test_top5_acc:88.7500
# epoch:143,train_loss:0.1238,train_acc:95.9920,train_top5_acc:99.9300,test_loss:1.8448,test_acc:66.6200,test_top5_acc:88.6600
# epoch:144,train_loss:0.1225,train_acc:96.1540,train_top5_acc:99.9140,test_loss:1.9026,test_acc:65.5300,test_top5_acc:88.4100
# epoch:145,train_loss:0.1201,train_acc:96.1820,train_top5_acc:99.9420,test_loss:1.8546,test_acc:66.2600,test_top5_acc:88.5200
# epoch:146,train_loss:0.1273,train_acc:95.9740,train_top5_acc:99.9260,test_loss:1.7624,test_acc:66.4800,test_top5_acc:88.5800
# epoch:147,train_loss:0.1201,train_acc:96.1220,train_top5_acc:99.9220,test_loss:1.8084,test_acc:67.6200,test_top5_acc:88.7400
# epoch:148,train_loss:0.1110,train_acc:96.4900,train_top5_acc:99.9260,test_loss:1.8247,test_acc:67.1800,test_top5_acc:88.6200
# epoch:149,train_loss:0.1055,train_acc:96.6840,train_top5_acc:99.9380,test_loss:1.7918,test_acc:67.6000,test_top5_acc:88.9700
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /tmp/ipykernel_1457/3607500583.py in <module>
#      17     test_top5_acca.append(test_top5_acc)
#      18
# ---> 19 save_plots(train_acca, test_acca, train_lossa, test_lossa, train_top5_acca, test_top5_acca, "vip_epoch=150")
#
# ~/basic_tools.py in save_plots(train_acc, test_acc, train_loss, test_loss, train_top5_correct, test_top5_correct, modelname, output_dir)
#      21     # Create directory if it doesn't exist.
#      22     if not os.path.exists(output_dir):
# ---> 23         os.makedirs(output_dir)
#      24     # Accuracy plots.
#      25     plt.figure(figsize=(10, 7))
#
# /opt/conda/lib/python3.7/os.py in makedirs(name, mode, exist_ok)
#     211     if head and tail and not path.exists(head):
#     212         try:
# --> 213             makedirs(head, exist_ok=exist_ok)
#     214         except FileExistsError:
#     215             # Defeats race condition when another thread created the path
#
# /opt/conda/lib/python3.7/os.py in makedirs(name, mode, exist_ok)
#     221             return
#     222     try:
# --> 223         mkdir(name, mode)
#     224     except OSError:
#     225         # Cannot rely on checking for EEXIST, since the operating system
#
# PermissionError: [Errno 13] Permission denied: '../train_process'

# %%
def save_plots(train_acc, test_acc, train_loss, test_loss,train_top5_correct,test_top5_correct,modelname,output_dir='./train_process'):
    """
    Function to save the loss and accuracy plots to disk.
    """
    if modelname==None:
        modelname='unnamed model'
    output_dir=output_dir+'/'+modelname
    # Create directory if it doesn't exist.
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    # Accuracy plots.
    plt.figure(figsize=(10, 7))
    plt.plot(train_acc, color="tab:blue", linestyle="-", label="train accuracy")
    plt.plot(test_acc, color="tab:red", linestyle="-", label="test accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.savefig(os.path.join(output_dir, modelname + "_accuracy.png"))

    # Loss plots.
    plt.figure(figsize=(10, 7))
    plt.plot(train_loss, color="tab:blue", linestyle="-", label="train loss")
    plt.plot(test_loss, color="tab:red", linestyle="-", label="test loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.savefig(os.path.join(output_dir, modelname + "_loss.png"))

    # Top5 accuracy plots.
    plt.figure(figsize=(10, 7))
    plt.plot(train_top5_correct, color="tab:blue", linestyle="-", label="train top5 accuracy")
    plt.plot(test_top5_correct, color="tab:red", linestyle="-", label="test top5 accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Top5 Accuracy")
    plt.legend()
    plt.savefig(os.path.join(output_dir, modelname + "_top5_accuracy.png"))
save_plots(train_acca, test_acca, train_lossa, test_lossa, train_top5_acca, test_top5_acca, "resnet+permuteMLP_new=150")

# %%
modelpath='./models/'
if not os.path.exists(modelpath):
    os.makedirs(modelpath)
model_name = 'resnet18+permuteMLP'
torch.save(model.state_dict(),modelpath+model_name+'.pth')
